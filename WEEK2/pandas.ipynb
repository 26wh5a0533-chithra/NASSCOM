# %%
import pandas as pd
import numpy as np
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print("\nSeries:")
print(s)
data = {
    'Name': ['Ammulu', 'Bhavya', 'Chithra', 'Divya'],
    'Age': [12, 20, 19, 30],
    'Salary': [150000, 620000, 170000, 180000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# DataFrame:
#       Name  Age  Salary
# 0   Ammulu   12  150000
# 1   Bhavya   20  620000
# 2  Chithra   19  170000
# 3    Divya   30  180000

# %%
array = np.array([[18, 22], [13, 4], [25, 36]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0       18       22
# 1       13        4
# 2       25       36

# %%
print("\nRow with label 3 using loc:")
print(df.loc[3])
# Out:
# Row with label 3 using loc:
# Name       Divya
# Age           30
# Salary    180000
# Name: 3, dtype: object

# %%
print("\nFirst two rows using iloc:")
print(df.iloc[0:3])
# Out:
# First two rows using iloc:
#       Name  Age  Salary
# 0   Ammulu   12  150000
# 1   Bhavya   20  620000
# 2  Chithra   19  170000

# %%
print("\nSelect 'Name' column:")
print(df['Name'])
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])
print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 160000])
# Out:
# Select 'Name' column:
# 0     Ammulu
# 1     Bhavya
# 2    Chithra
# 3      Divya
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0   Ammulu   12
# 1   Bhavya   20
# 2  Chithra   19
# 3    Divya   30
#
# Rows where Salary > 60000:
#       Name  Age  Salary
# 1   Bhavya   20  620000
# 2  Chithra   19  170000
# 3    Divya   30  180000

# %%
data_dirty = {
    'Name': ['Amma', 'Bhavani', None, 'Durga'],
    'Age': [250, None, 350, 400],
    'Salary': [150000, 600000, None, 180000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)
# Out:
# Original Dirty DataFrame:
#       Name    Age    Salary
# 0     Amma  250.0  150000.0
# 1  Bhavani    NaN  600000.0
# 2     None  350.0       NaN
# 3    Durga  400.0  180000.0

# %%
print("\nDrop rows with any NaN values:")
print(df_dirty.dropna())
print("\nFill missing values with a specific value:")
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))
# Out:
# Drop rows with any NaN values:
#     Name    Age    Salary
# 0   Amma  250.0  150000.0
# 3  Durga  400.0  180000.0
#
# Fill missing values with a specific value:
#       Name         Age    Salary
# 0     Amma  250.000000  150000.0
# 1  Bhavani  333.333333  600000.0
# 2  Unknown  350.000000       0.0
# 3    Durga  400.000000  180000.0

# %%
print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df)
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus column:
#       Name  Age  Salary    Bonus
# 0   Ammulu   12  150000  15000.0
# 1   Bhavya   20  620000  62000.0
# 2  Chithra   19  170000  17000.0
# 3    Divya   30  180000  18000.0
#
# Rename columns:
#       Name  Age  BaseSalary    Bonus
# 0   Ammulu   12      150000  15000.0
# 1   Bhavya   20      620000  62000.0
# 2  Chithra   19      170000  17000.0
# 3    Divya   30      180000  18000.0
#
# Sort by Age descending:
#       Name  Age  Salary    Bonus
# 3    Divya   30  180000  18000.0
# 1   Bhavya   20  620000  62000.0
# 2  Chithra   19  170000  17000.0
# 0   Ammulu   12  150000  15000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    280000.0
# Name: Salary, dtype: float64

# %%
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
# Out:
# Rename columns:
#       Name  Age  BaseSalary    Bonus  AgeGroup
# 0   Ammulu   12      150000  15000.0     False
# 1   Bhavya   20      620000  62000.0     False
# 2  Chithra   19      170000  17000.0     False
# 3    Divya   30      180000  18000.0     False

# %%
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# Sort by Age descending:
#       Name  Age  Salary    Bonus  AgeGroup
# 3    Divya   30  180000  18000.0     False
# 1   Bhavya   20  620000  62000.0     False
# 2  Chithra   19  170000  17000.0     False
# 0   Ammulu   12  150000  15000.0     False
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    280000.0
# Name: Salary, dtype: float64

# %%
np.random.seed(1)
num_rows = 10
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})

print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5

# %%
print("\nDataFrame info:")
df.info()
print("\nDataFrame describe:")
print(df.describe())
# Out:
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   Salary    4 non-null      int64
#  3   Bonus     4 non-null      float64
#  4   AgeGroup  4 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 264.0+ bytes
#
# DataFrame describe:
#              Age         Salary         Bonus
# count   4.000000       4.000000      4.000000
# mean   20.250000  280000.000000  28000.000000
# std     7.410578  227009.544586  22700.954459
# min    12.000000  150000.000000  15000.000000
# 25%    17.250000  165000.000000  16500.000000
# 50%    19.500000  175000.000000  17500.000000
# 75%    22.500000  290000.000000  29000.000000
# max    30.000000  620000.000000  62000.000000

# %%
print("\nData types of each column:")
print(df.dtypes)
print("\nFirst 3 rows:")
print(df.head(3))
print("\nLast 2 rows:")
print(df.tail(2))
# Out:
# Data types of each column:
# Name         object
# Age           int64
# Salary        int64
# Bonus       float64
# AgeGroup       bool
# dtype: object
#
# First 3 rows:
#       Name  Age  Salary    Bonus  AgeGroup
# 0   Ammulu   12  150000  15000.0     False
# 1   Bhavya   20  620000  62000.0     False
# 2  Chithra   19  170000  17000.0     False
#
# Last 2 rows:
#       Name  Age  Salary    Bonus  AgeGroup
# 2  Chithra   19  170000  17000.0     False
# 3    Divya   30  180000  18000.0     False

# %%
print("\nMean Age:", df['Age'].mean())
print("Median Salary:", df['Salary'].median())
print("Mode of Bonus:")
print(df['Bonus'].mode())
print("Standard Deviation of Salary:", df['Salary'].std())
print("Variance of Salary:", df['Salary'].var())
# Out:
# Mean Age: 20.25
# Median Salary: 175000.0
# Mode of Bonus:
# 0    15000.0
# 1    17000.0
# 2    18000.0
# 3    62000.0
# Name: Bonus, dtype: float64
# Standard Deviation of Salary: 227009.54458641895
# Variance of Salary: 51533333333.333336

# %%
print("\nCorrelation between Age and Salary:")
print(df[['Age', 'Salary']].corr())
print("\nCovariance between Age and Salary:")
print(df[['Age', 'Salary']].cov())
print("\nValue counts for AgeGroup:")
print(df['AgeGroup'].value_counts())
# Out:
# Correlation between Age and Salary:
#              Age    Salary
# Age     1.000000  0.029722
# Salary  0.029722  1.000000
#
# Covariance between Age and Salary:
#                  Age        Salary
# Age        54.916667  5.000000e+04
# Salary  50000.000000  5.153333e+10
#
# Value counts for AgeGroup:
# AgeGroup
# False    4
# Name: count, dtype: int64

# %%
print("\nCumulative sum of Salary:")
print(df['Salary'].cumsum())
print("\nCumulative max of Salary:")
print(df['Salary'].cummax())
print("\nRank of Salary:")
print(df['Salary'].rank())
print("\nQuantiles of Salary:")
print(df['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Cumulative sum of Salary:
# 0     150000
# 1     770000
# 2     940000
# 3    1120000
# Name: Salary, dtype: int64
#
# Cumulative max of Salary:
# 0    150000
# 1    620000
# 2    620000
# 3    620000
# Name: Salary, dtype: int64
#
# Rank of Salary:
# 0    1.0
# 1    4.0
# 2    2.0
# 3    3.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    165000.0
# 0.50    175000.0
# 0.75    290000.0
# Name: Salary, dtype: float64

# %%
import pandas as pd
summary_data = {
    "Function": [
        "pd.Series()",
        "pd.DataFrame()",
        "df.head()",
        "df.tail()",
        "df.info()",
        "df.describe()",
        "df.dtypes",
        "df.loc[]",
        "df.iloc[]",
        "df['column']",
        "df[['col1','col2']]",
        "df.dropna()",
        "df.fillna()",
        "df.isnull()",
        "df.sort_values()",
        "df.groupby()",
        "df.mean(), median(), mode()",
        "df.std(), var()",
        "df.corr(), cov()",
        "df.value_counts()",
        "df.cumsum(), cummax()",
        "df.rank()",
        "df.quantile()",
        "pd.read_csv()",
        "pd.read_excel()",
        "pd.read_json()"
    ],
    "Purpose": [
        "Create a one-dimensional labeled array",
        "Create a 2D labeled data structure",
        "Display first n rows",
        "Display last n rows",
        "Summary including non-null values, types",
        "Statistical summary of numerical columns",
        "Data types of each column",
        "Label-based row/column selection",
        "Position-based row/column selection",
        "Select a single column",
        "Select multiple columns",
        "Remove rows with missing values",
        "Fill missing values",
        "Check for missing values",
        "Sort by column values",
        "Group data and apply aggregation",
        "Central tendency stats",
        "Spread or dispersion stats",
        "Relationships between columns",
        "Frequency of values",
        "Cumulative operations",
        "Ranks of data",
        "Get quantiles",
        "Read CSV file",
        "Read Excel file",
        "Read JSON file"
    ]
}
summary_df = pd.DataFrame(summary_data)
print("\nSummary of Important Pandas Functions:")
print(summary_df)
# Out:
# Summary of Important Pandas Functions:
#                        Function                                   Purpose
# 0                   pd.Series()    Create a one-dimensional labeled array
# 1                pd.DataFrame()        Create a 2D labeled data structure
# 2                     df.head()                      Display first n rows
# 3                     df.tail()                       Display last n rows
# 4                     df.info()  Summary including non-null values, types
# 5                 df.describe()  Statistical summary of numerical columns
# 6                     df.dtypes                 Data types of each column
# 7                      df.loc[]          Label-based row/column selection
# 8                     df.iloc[]       Position-based row/column selection
# 9                  df['column']                    Select a single column
# 10          df[['col1','col2']]                   Select multiple columns
# 11                  df.dropna()           Remove rows with missing values
# 12                  df.fillna()                       Fill missing values
# 13                  df.isnull()                  Check for missing values
# 14             df.sort_values()                     Sort by column values
# 15                 df.groupby()          Group data and apply aggregation
# 16  df.mean(), median(), mode()                    Central tendency stats
# 17              df.std(), var()                Spread or dispersion stats
# 18             df.corr(), cov()             Relationships between columns
# 19            df.value_counts()                       Frequency of values
# 20        df.cumsum(), cummax()                     Cumulative operations
# 21                    df.rank()                             Ranks of data
# 22                df.quantile()                             Get quantiles
# 23                pd.read_csv()                             Read CSV file
# 24              pd.read_excel()                           Read Excel file
# 25               pd.read_json()                            Read JSON file
