# %%
print("Hello, Python!")


if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, Python!
# This is indented correctly.

# %%
name ="Chithra"
age = 18
height = 5.2

print("Name:", name)
print("Age:", age)
print("Height:", height)

name = 123
print("New value of name:", name)
# Out:
# Name: Chithra
# Age: 18
# Height: 5.2
# New value of name: 123

# %%
a=100
b=3.54
c="String"
d=True
e=[1,5,6,"chithra"]
f={"Name":"Laxmi","Age":18}
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# 100
# 3.54
# String
# True
# [1, 5, 6, 'chithra']
# {'Name': 'Laxmi', 'Age': 18}
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'dict'>

# %%
print("Welcome to Python I/O! and NASSCOM lab")
# Out:
# Welcome to Python I/O! and NASSCOM lab

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: Laxmichithra
# Hello, Laxmichithra

# %%
user_age = int(input("Enter your age: "))
print("You will age be", user_age + 1, "next year.")
# Out:
# Enter your age: 19
# You will age be 20 next year.
