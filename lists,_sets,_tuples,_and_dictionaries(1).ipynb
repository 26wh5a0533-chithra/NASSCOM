# %%
fruits = ['Mango', 'banana', 'cherry', 'apple']
print("Original list:", fruits)
print("First fruit:", fruits[0])
# Out:
# Original list: ['Mango', 'banana', 'cherry', 'apple']
# First fruit: Mango

# %%
fruits.append('KIWI')
print("After appending:", fruits)
# Out:
# After appending: ['Mango', 'banana', 'cherry', 'apple', 'orange', 'KIWI']

# %%
fruits.remove('banana')
print("After removing banana:", fruits)
print("Number of fruits:", len(fruits))
# Out:
# After removing banana: ['Mango', 'cherry', 'apple', 'orange', 'KIWI']
# Number of fruits: 5

# %%
dimensions = (10, 60, 80)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 60, 80)

# %%
print("Third element:", dimensions[2])
# Out:
# Third element: 80

# %%
unique_numbers = {1, 2, 3, 2,2,4, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3, 4}

# %%
unique_numbers.add(6)
print("After adding 6:", unique_numbers)
# Out:
# After adding 6: {1, 2, 3, 4, 6}

# %%
unique_numbers.remove(1)
print("After removing 1:", unique_numbers)
# Out:
# After removing 1: {3, 4}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Chithra',
    'age': 19,
    'course': 'CyberSecurity'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Chithra', 'age': 19, 'course': 'CyberSecurity'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Chithra

# %%
student['grade'] = 'A+'
print("After adding grade:", student)
del student['age']
print("After deleting age:", student)
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Chithra', 'age': 19, 'course': 'CyberSecurity', 'grade': 'A+'}
# After deleting age: {'name': 'Chithra', 'course': 'CyberSecurity', 'grade': 'A+'}
# name: Chithra
# course: CyberSecurity
# grade: A+

# %%
keys = ['id', 'name', 'marks']
values = [101, 'Laxmi', 95]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'Laxmi', 'marks': 95}
